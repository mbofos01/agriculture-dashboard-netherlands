# %%
# !pip install keras_tuner
# !pip install scikeras
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.32.3)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras_tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras_tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.6 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %% [markdown]
# #DATA PREPROCESSING

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import joblib

#load and sort the data
data = pd.read_csv('/content/merged_data_v0.1.csv')
data['Month-Year'] = pd.to_datetime(data['Month-Year'], format='%b-%y')
data = data.sort_values('Month-Year').reset_index(drop=True)
data_features = data.drop(columns=['Month-Year'])

num_years = len(data) // 12

# Get 80% of the years as training and 20% as testing
num_train_years = int(num_years * 0.8)
split_index = num_train_years * 12

# Split the data into training and testing sets
train_data = data[:split_index]
test_data = data[split_index:]


train_features = train_data.drop(columns=['Month-Year'])
test_features = test_data.drop(columns=['Month-Year'])

# Normalize features based on the training data and save scaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_features = scaler.fit_transform(train_features)
scaled_test_features = scaler.transform(test_features)

joblib.dump(scaler, 'scaler.pkl')

#Split into X and Y for training and testing
sequence_length = 12
X_train, y_train = [], []
for i in range(sequence_length, len(scaled_train_features)):
    X_train.append(scaled_train_features[i - sequence_length:i])
    y_train.append(scaled_train_features[i])

X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = [], []
for i in range(sequence_length, len(scaled_test_features)):
    X_test.append(scaled_test_features[i - sequence_length:i])
    y_test.append(scaled_test_features[i])

X_test, y_test = np.array(X_test), np.array(y_test)
# Out:
# Input shape (X): (1164, 12, 9), Output shape (y): (1164, 9)

# %% [markdown]
# #LSTM MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

# Create 3 lstm layers with dropout
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.1))

model.add(LSTM(units=64))
model.add(Dropout(0.1))

# Output dense layer
model.add(Dense(units=y_train.shape[1]))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 0.1264 - val_loss: 0.0447
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0475 - val_loss: 0.0479
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0418 - val_loss: 0.0468
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0406 - val_loss: 0.0504
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0370 - val_loss: 0.0450
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0325 - val_loss: 0.0376
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0314 - val_loss: 0.0245
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0262 - val_loss: 0.0195
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0253 - val_loss: 0.0222
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0221 - val_loss: 0.0189
# Epoch 11/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0205 - val_loss: 0.0142
# Epoch 12/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0192 - val_loss: 0.0140
# Epoch 13/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0193 - val_loss: 0.0134
# Epoch 14/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0183 - val_loss: 0.0143
# Epoch 15/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 0.0188 - val_loss: 0.0127
# Epoch 16/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0174 - val_loss: 0.0152
# Epoch 17/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0181 - val_loss: 0.0132
# Epoch 18/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0169 - val_loss: 0.0151
# Epoch 19/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0179 - val_loss: 0.0130
# Epoch 20/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0173 - val_loss: 0.0124
# Epoch 21/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0163 - val_loss: 0.0125
# Epoch 22/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0176 - val_loss: 0.0134
# Epoch 23/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0164 - val_loss: 0.0124
# Epoch 24/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0155 - val_loss: 0.0141
# Epoch 25/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0170 - val_loss: 0.0123
# Epoch 26/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0156 - val_loss: 0.0141
# Epoch 27/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0162 - val_loss: 0.0115
# Epoch 28/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0162 - val_loss: 0.0118
# Epoch 29/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0170 - val_loss: 0.0134
# Epoch 30/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0153 - val_loss: 0.0123
# Epoch 31/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0150 - val_loss: 0.0128
# Epoch 32/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0162 - val_loss: 0.0123
# Epoch 33/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0160 - val_loss: 0.0123
# Epoch 34/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0149 - val_loss: 0.0137
# Epoch 35/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0161 - val_loss: 0.0115
# Epoch 36/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0149 - val_loss: 0.0133
# Epoch 37/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0157 - val_loss: 0.0120
# Epoch 38/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0156 - val_loss: 0.0134
# Epoch 39/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0146 - val_loss: 0.0125
# Epoch 40/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0145 - val_loss: 0.0119
# Epoch 41/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0146 - val_loss: 0.0114
# Epoch 42/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0142 - val_loss: 0.0118
# Epoch 43/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0140 - val_loss: 0.0112
# Epoch 44/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0150 - val_loss: 0.0111
# Epoch 45/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0146 - val_loss: 0.0115
# Epoch 46/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0147 - val_loss: 0.0113
# Epoch 47/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0133 - val_loss: 0.0113
# Epoch 48/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0144 - val_loss: 0.0119
# Epoch 49/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0153 - val_loss: 0.0115
# Epoch 50/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0143 - val_loss: 0.0105
# Epoch 51/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0140 - val_loss: 0.0120
# Epoch 52/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0143 - val_loss: 0.0111
# Epoch 53/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0143 - val_loss: 0.0111
# Epoch 54/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0131 - val_loss: 0.0111
# Epoch 55/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0138 - val_loss: 0.0121
# Epoch 56/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0139 - val_loss: 0.0107
# Epoch 57/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0136 - val_loss: 0.0119
# Epoch 58/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0140 - val_loss: 0.0105
# Epoch 59/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 0.0139 - val_loss: 0.0116
# Epoch 60/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0136 - val_loss: 0.0111
# Epoch 61/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0138 - val_loss: 0.0110
# Epoch 62/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0134 - val_loss: 0.0109
# Epoch 63/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0134 - val_loss: 0.0108
# Epoch 64/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0136 - val_loss: 0.0116
# Epoch 65/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0134 - val_loss: 0.0112
# Epoch 66/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0130 - val_loss: 0.0118
# Epoch 67/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0135 - val_loss: 0.0107
# Epoch 68/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0144 - val_loss: 0.0108
# Epoch 69/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0130 - val_loss: 0.0120
# Epoch 70/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0132 - val_loss: 0.0109
# Epoch 71/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0137 - val_loss: 0.0114
# Epoch 72/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0128 - val_loss: 0.0109
# Epoch 73/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0133 - val_loss: 0.0108
# Epoch 74/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0137 - val_loss: 0.0111
# Epoch 75/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0136 - val_loss: 0.0116
# Epoch 76/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0129 - val_loss: 0.0109
# Epoch 77/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.0124 - val_loss: 0.0111
# Epoch 78/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0138 - val_loss: 0.0108
# Epoch 79/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0131 - val_loss: 0.0104
# Epoch 80/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0136 - val_loss: 0.0108
# Epoch 81/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0124 - val_loss: 0.0105
# Epoch 82/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 83/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0127 - val_loss: 0.0116
# Epoch 84/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0137 - val_loss: 0.0104
# Epoch 85/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0124 - val_loss: 0.0106
# Epoch 86/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0132 - val_loss: 0.0104
# Epoch 87/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0140 - val_loss: 0.0110
# Epoch 88/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0131 - val_loss: 0.0110
# Epoch 89/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0133 - val_loss: 0.0110
# Epoch 90/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0129 - val_loss: 0.0111
# Epoch 91/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0118 - val_loss: 0.0119
# Epoch 92/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0132 - val_loss: 0.0106
# Epoch 93/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0134 - val_loss: 0.0111
# Epoch 94/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0130 - val_loss: 0.0111
# Epoch 95/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.0127 - val_loss: 0.0111
# Epoch 96/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0131 - val_loss: 0.0111
# Epoch 97/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 0.0130 - val_loss: 0.0107
# Epoch 98/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0131 - val_loss: 0.0105
# Epoch 99/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0127 - val_loss: 0.0108
# Epoch 100/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0125 - val_loss: 0.0109
# Epoch 101/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0120 - val_loss: 0.0105
# Epoch 102/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0123 - val_loss: 0.0105
# Epoch 103/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0123 - val_loss: 0.0110
# Epoch 104/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0129 - val_loss: 0.0106
# Epoch 105/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0122 - val_loss: 0.0102
# Epoch 106/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 107/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0120 - val_loss: 0.0106
# Epoch 108/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0124 - val_loss: 0.0108
# Epoch 109/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0124 - val_loss: 0.0106
# Epoch 110/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0130 - val_loss: 0.0105
# Epoch 111/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0125 - val_loss: 0.0111
# Epoch 112/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 113/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0128 - val_loss: 0.0111
# Epoch 114/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 115/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0119 - val_loss: 0.0104
# Epoch 116/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0120 - val_loss: 0.0114
# Epoch 117/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0124 - val_loss: 0.0105
# Epoch 118/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 119/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0127 - val_loss: 0.0106
# Epoch 120/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0116 - val_loss: 0.0106
# Epoch 121/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 122/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0122 - val_loss: 0.0108
# Epoch 123/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0117 - val_loss: 0.0107
# Epoch 124/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0130 - val_loss: 0.0107
# Epoch 125/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0119 - val_loss: 0.0106
# Epoch 126/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 127/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 128/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0121 - val_loss: 0.0104
# Epoch 129/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0123 - val_loss: 0.0104
# Epoch 130/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0119 - val_loss: 0.0106
# Epoch 131/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0125 - val_loss: 0.0109
# Epoch 132/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 133/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0120 - val_loss: 0.0103
# Epoch 134/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0120 - val_loss: 0.0107
# Epoch 135/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 136/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 137/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 138/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 139/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0113 - val_loss: 0.0109
# Epoch 140/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 141/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 142/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 143/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 144/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0117 - val_loss: 0.0105
# Epoch 145/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 146/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0123 - val_loss: 0.0106
# Epoch 147/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 0.0119 - val_loss: 0.0108
# Epoch 148/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0116 - val_loss: 0.0111
# Epoch 149/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0117 - val_loss: 0.0115
# Epoch 150/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0139 - val_loss: 0.0109
# Epoch 151/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0127 - val_loss: 0.0104
# Epoch 152/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0116 - val_loss: 0.0107
# Epoch 153/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 154/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 155/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 156/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0115 - val_loss: 0.0107
# Epoch 157/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0115 - val_loss: 0.0113
# Epoch 158/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0116 - val_loss: 0.0109
# Epoch 159/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0114 - val_loss: 0.0110
# Epoch 160/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0122 - val_loss: 0.0108
# Epoch 161/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0117 - val_loss: 0.0106
# Epoch 162/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0115 - val_loss: 0.0108
# Epoch 163/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.0117 - val_loss: 0.0115
# Epoch 164/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0109 - val_loss: 0.0107
# Epoch 165/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 166/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0116 - val_loss: 0.0124
# Epoch 167/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 168/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0112 - val_loss: 0.0110
# Epoch 169/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 170/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 171/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0120 - val_loss: 0.0107
# Epoch 172/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0110 - val_loss: 0.0115
# Epoch 173/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 174/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 175/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0113 - val_loss: 0.0111
# Epoch 176/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 177/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 178/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 179/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0114 - val_loss: 0.0113
# Epoch 180/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0113 - val_loss: 0.0113
# Epoch 181/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0119 - val_loss: 0.0115
# Epoch 182/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0111 - val_loss: 0.0104
# Epoch 183/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0112 - val_loss: 0.0106
# Epoch 184/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 185/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 186/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 187/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 188/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0115 - val_loss: 0.0109
# Epoch 189/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0113 - val_loss: 0.0112
# Epoch 190/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 191/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0110 - val_loss: 0.0120
# Epoch 192/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0127 - val_loss: 0.0120
# Epoch 193/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 194/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0125 - val_loss: 0.0110
# Epoch 195/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 196/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0112 - val_loss: 0.0107
# Epoch 197/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0114 - val_loss: 0.0112
# Epoch 198/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0106 - val_loss: 0.0123
# Epoch 199/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 200/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0107 - val_loss: 0.0109

# %% [markdown]
# #PREDICT

# %%
# Found the total number of years in the data
num_test_years = len(test_data) // 12

#List for predictions
all_predictions = []

# Loop through each year in the test set
for year in range(min(num_test_years, len(X_test) // 12)):

    #Get the data for each year
    start_index = year * 12
    last_sequence = X_test[start_index]

    # Current prediction list
    year_predictions = []

    # Predict for the next 12 months of the current year
    for _ in range(12):
        # Predict the next month
        next_pred = model.predict(np.array([last_sequence]))

        # Inverse transform the prediction to get actual values
        next_pred_actual = scaler.inverse_transform(next_pred)
        year_predictions.append(next_pred_actual[0])

        # Update the sequence by removing the first month and adding the prediction at the end
        next_sequence = np.append(last_sequence[1:], next_pred, axis=0)
        last_sequence = next_sequence

    # Append the predictions for the current year to the overall predictions list
    all_predictions.extend(year_predictions)

# Convert all predictions to a DataFrame
predictions_df = pd.DataFrame(all_predictions, columns=data_features.columns)
print(predictions_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#      Cloud cover  Frost days  potential evapo-transpiration  \
# 0      81.905571   14.704679                       0.544278
# 1      78.985664   15.515803                       0.683402
# 2      74.975960   13.203222                       1.079879
# 3      69.715569    8.583906                       1.830154
# 4      69.479752    3.565066                       2.540078
# ..           ...         ...                            ...
# 283    65.918503   -0.036907                       3.049030
# 284    68.021790   -0.360433                       2.024138
# 285    74.868958    2.767357                       1.127963
# 286    80.549789    7.511258                       0.703209
# 287    83.106712   12.227442                       0.459507
#
#      Precipitation rate  Minimum 2m temperature  Mean 2m temperature  \
# 0             64.467766                0.752861             3.219437
# 1             55.080170                0.251993             3.025807
# 2             51.557755                1.329988             4.731307
# 3             46.507896                3.380429             7.509576
# 4             52.057308                6.620707            11.196549
# ..                  ...                     ...                  ...
# 283           66.689499               12.852071            17.363892
# 284           63.555393               10.464191            14.737803
# 285           75.355621                6.624891            10.121361
# 286           80.423691                3.995941             6.735264
# 287           76.818863                1.916382             4.350948
#
#      Maximum 2m temperature  Vapour pressure   Wet days
# 0                  5.817361         6.751834  17.277786
# 1                  5.950949         6.599917  15.365096
# 2                  8.248016         7.128314  14.718305
# 3                 11.742637         8.130394  13.652299
# 4                 15.708285        10.184167  13.684504
# ..                      ...              ...        ...
# 283               22.002001        15.415682  13.506767
# 284               19.126543        13.598372  14.718367
# 285               13.687499        10.661867  16.616282
# 286                9.524614         8.593501  18.707438
# 287                6.772054         7.336378  19.411039
#
# [288 rows x 9 columns]

# %% [markdown]
# #EVALUATION

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

actual_values = test_features.iloc[12:].values
model_predictions = predictions_df.iloc[:]
baseline_predictions = test_features.iloc[:-12].values

lstm_mae = mean_absolute_error(actual_values, model_predictions)
lstm_mse = mean_squared_error(actual_values, model_predictions)
lstm_rmse = np.sqrt(lstm_mse)
lstm_r2 = r2_score(actual_values, model_predictions)

baseline_mae = mean_absolute_error(actual_values, baseline_predictions)
baseline_mse = mean_squared_error(actual_values, baseline_predictions)
baseline_rmse = np.sqrt(baseline_mse)
baseline_r2 = r2_score(actual_values, baseline_predictions)

# Print metrics

print(f"LSTM MAE: {lstm_mae}")
print(f'LSTM MSE: {lstm_mse}')
print(f'LSTM RMSE: {lstm_rmse}')
print(f'LSTM R²: {lstm_r2}')
print("-----------------------------")
print(f"Base MAE: {baseline_mae}")
print(f'Base MSE: {baseline_mse}')
print(f'Base RMSE: {baseline_rmse}')
print(f'Base R²: {baseline_r2}')
# Out:
# LSTM MAE: 4.1741691367841725
# LSTM MSE: 93.12444516807987
# LSTM RMSE: 9.650100785384568
# LSTM R²: 0.6638381642198322
# -----------------------------
# Base MAE: 5.467283950617284
# Base MSE: 171.44037037037037
# Base RMSE: 13.093523985939399
# Base R²: 0.4217153472141438

# %%
model.save('/content/model.keras')

# %% [markdown]
# #2024 PREDICTION

# %%
import pandas as pd
import joblib
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('/content/model.keras')
#Read and get the data of the last year
data = pd.read_csv('/content/merged_data_v0.1.csv')

# data['Month-Year'] = pd.to_datetime(data['Month-Year'], format='%b-%y')
# data = data.sort_values('Month-Year').reset_index(drop=True)
data_features = data.drop(columns=['Month-Year'])

test_data = data.tail(12)

test_features = test_data.drop(columns=['Month-Year'])

#Scale the data based on the saved scaler
scaler = joblib.load('scaler.pkl')
scaled_test_features = scaler.transform(test_features)


X_test = []
X_test.append(scaled_test_features)
X_test = np.array(X_test)

# %%
last_sequence = X_test[0]
year_predictions = []

# Predict the next 12 months
for _ in range(12):

    # Predict the next month
    next_pred = model.predict(np.array([last_sequence]))

    # Inverse transform the prediction to get actual values
    next_pred_actual = scaler.inverse_transform(next_pred)
    year_predictions.append(next_pred_actual[0])

    # Update the sequence by removing the first month and adding the prediction at the end
    next_sequence = np.append(last_sequence[1:], next_pred, axis=0)
    last_sequence = next_sequence



# Convert all predictions to a DataFrame
predictions_df = pd.DataFrame(year_predictions, columns=data_features.columns)
print(predictions_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#     Cloud cover  Frost days  potential evapo-transpiration  \
# 0     84.022560   13.062772                       0.466247
# 1     82.619919   13.426487                       0.507050
# 2     76.637177   12.374729                       1.043257
# 3     72.395332    7.433807                       1.748650
# 4     69.662392    1.550668                       2.597731
# 5     69.630615    0.378478                       2.822640
# 6     65.191986   -0.316868                       3.365325
# 7     51.408909   -1.130540                       3.961799
# 8     56.548027   -0.345048                       3.130083
# 9     73.820282    1.065002                       1.444833
# 10    79.142403    6.834790                       0.790175
# 11    84.218750   11.843580                       0.503701
#
#     Precipitation rate  Minimum 2m temperature  Mean 2m temperature  \
# 0            79.761589                1.841625             4.301898
# 1            71.766945                1.484284             4.088207
# 2            60.711849                1.812532             5.076066
# 3            52.273643                3.812534             7.802710
# 4            52.258774                7.039632            11.584026
# 5            61.785545                9.105827            13.592829
# 6            62.366001               11.895310            16.677404
# 7            47.779144               14.383464            19.664883
# 8            56.314487               13.157911            18.109900
# 9            77.391922                8.719587            12.556381
# 10           70.950607                4.116344             7.157773
# 11           73.564011                2.261024             4.684944
#
#     Maximum 2m temperature  Vapour pressure   Wet days
# 0                 6.780494         7.419712  20.397436
# 1                 6.682900         7.269090  19.156849
# 2                 8.321642         7.414882  16.983952
# 3                11.811548         8.459867  14.782395
# 4                16.098360        10.456791  13.254007
# 5                17.903088        12.202513  13.429764
# 6                21.268213        14.524498  12.545455
# 7                25.265299        16.652763   8.898136
# 8                23.223421        15.881118  11.344948
# 9                16.318373        12.182702  16.866718
# 10               10.171317         8.838364  16.906904
# 11                7.162333         7.630477  18.362989

# %%
#conver the monthly data into yearly
yearly_summary = predictions_df.agg({
    'Frost days': 'sum',
    'Wet days': 'sum',
    'Precipitation rate': 'mean',
    'Minimum 2m temperature': 'mean',
    'Mean 2m temperature': 'mean',
    'Maximum 2m temperature': 'mean',
    'potential evapo-transpiration': 'mean',
    'Cloud cover': 'mean',
    'Vapour pressure': 'mean'
}).reset_index()

yearly_summary.to_csv('2024_prediction.csv', index=False)
